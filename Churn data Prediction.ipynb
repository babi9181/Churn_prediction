# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\\Users\\abhin\\Downloads\\telecom_customer_churn.csv")
df
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# ...

# %%
df.shape
# Out:
# (7043, 38)

# %%
df.size
# Out:
# 267634

# %%
df.dtypes
# Out:
# Customer ID                           object
# Gender                                object
# Age                                    int64
# Married                               object
# Number of Dependents                   int64
# City                                  object
# Zip Code                               int64
# Latitude                             float64
# Longitude                            float64
# Number of Referrals                    int64
# Tenure in Months                       int64
# Offer                                 object
# Phone Service                         object
# Avg Monthly Long Distance Charges    float64
# Multiple Lines                        object
# Internet Service                      object
# Internet Type                         object
# Avg Monthly GB Download              float64
# Online Security                       object
# Online Backup                         object
# Device Protection Plan                object
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %%
# df.values

# %%
df.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# ...

# %%
df
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# ...

# %%
cat=df.select_dtypes(include=['object']).columns
num=df.select_dtypes(exclude=['object']).columns

# %%
print('cat:',cat)
print('num:',num)
# Out:
# cat: Index(['Customer ID', 'Gender', 'Married', 'City', 'Offer', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Internet Type',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Customer Status', 'Churn Category', 'Churn Reason'],
#       dtype='object')
# num: Index(['Age', 'Number of Dependents', 'Zip Code', 'Latitude', 'Longitude',
#        'Number of Referrals', 'Tenure in Months',
#        'Avg Monthly Long Distance Charges', 'Avg Monthly GB Download',
#        'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue'],
#       dtype='object')

# %%
df.drop('Churn Reason',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
#        'City', 'Zip Code', 'Latitude', 'Longitude', 'Number of Referrals',
#        'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Customer Status', 'Churn Category'],
#       dtype='object')

# %%
cols=['Churn Category','Customer ID','Latitude', 'Longitude','Offer','Total Long Distance Charges','Total Charges']
df.drop(cols,axis=1,inplace=True)

# %%
df.shape
# Out:
# (7043, 30)

# %%
df
# Out:
#       Gender  Age Married  Number of Dependents          City  Zip Code  \
# 0     Female   37     Yes                     0  Frazier Park     93225
# 1       Male   46      No                     0      Glendale     91206
# 2       Male   50      No                     0    Costa Mesa     92627
# 3       Male   78     Yes                     0      Martinez     94553
# 4     Female   75     Yes                     0     Camarillo     93010
# ...      ...  ...     ...                   ...           ...       ...
# 7038  Female   20      No                     0       La Mesa     91941
# 7039    Male   40     Yes                     0     Riverbank     95367
# 7040    Male   22      No                     0           Elk     95432
# 7041    Male   21     Yes                     0  Solana Beach     92075
# 7042    Male   36     Yes                     0   Sierra City     96125
#
#       Number of Referrals  Tenure in Months Phone Service  \
# ...

# %%
df.drop('Zip Code',inplace=True,axis=1)

# %%
df.shape
# Out:
# (7043, 29)

# %%
num1=df.select_dtypes(include=['float64','int64']).columns
cat1=df.select_dtypes(include=['object']).columns
len(num1)
len(cat1)
# Out:
# 19

# %%
df[num1]=df[num1].fillna(df[num1].median())

# %%
df[cat1]=df[cat1].fillna(df[cat1].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# Gender                               0
# Age                                  0
# Married                              0
# Number of Dependents                 0
# City                                 0
# Number of Referrals                  0
# Tenure in Months                     0
# Phone Service                        0
# Avg Monthly Long Distance Charges    0
# Multiple Lines                       0
# Internet Service                     0
# Internet Type                        0
# Avg Monthly GB Download              0
# Online Security                      0
# Online Backup                        0
# Device Protection Plan               0
# Premium Tech Support                 0
# Streaming TV                         0
# Streaming Movies                     0
# Streaming Music                      0
# Unlimited Data                       0
# Contract                             0
# Paperless Billing                    0
# Payment Method                       0
# ...

# %% [markdown]
# **Outlier Analysis**

# %%
num1
# Out:
# Index(['Age', 'Number of Dependents', 'Number of Referrals',
#        'Tenure in Months', 'Avg Monthly Long Distance Charges',
#        'Avg Monthly GB Download', 'Monthly Charge', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Revenue'],
#       dtype='object')

# %%
for i in num1:
    d_count=round(df[i].count(),2)
    d_max=round(df[i].max(),2)
    d_min=round(df[i].min(),2)
    d_mean=round(df[i].mean(),2)
    d_median=round(df[i].median(),2)
    d_std=round(df[i].std(),2)

    print(i,'count:',d_count)
    print(i,'max:',d_max)
    print(i,'min:',d_min)
    print(i,'mean:',d_mean)
    print(i,'median:',d_median)
    print(i,'std:',d_std)
    print('------------------------------------')
# Out:
# Age count: 7043
# Age max: 80
# Age min: 19
# Age mean: 46.51
# Age median: 46.0
# Age std: 16.75
# ------------------------------------
# Number of Dependents count: 7043
# Number of Dependents max: 9
# Number of Dependents min: 0
# Number of Dependents mean: 0.47
# Number of Dependents median: 0.0
# Number of Dependents std: 0.96
# ------------------------------------
# Number of Referrals count: 7043
# Number of Referrals max: 11
# Number of Referrals min: 0
# Number of Referrals mean: 1.95
# Number of Referrals median: 0.0
# Number of Referrals std: 3.0
# ------------------------------------
# Tenure in Months count: 7043
# Tenure in Months max: 72
# Tenure in Months min: 1
# Tenure in Months mean: 32.39
# Tenure in Months median: 29.0
# Tenure in Months std: 24.54
# ------------------------------------
# Avg Monthly Long Distance Charges count: 7043
# Avg Monthly Long Distance Charges max: 49.99
# Avg Monthly Long Distance Charges min: 1.01
# ...

# %%
df.describe()
# Out:
#                Age  Number of Dependents  Number of Referrals  \
# count  7043.000000           7043.000000          7043.000000
# mean     46.509726              0.468692             1.951867
# std      16.750352              0.962802             3.001199
# min      19.000000              0.000000             0.000000
# 25%      32.000000              0.000000             0.000000
# 50%      46.000000              0.000000             0.000000
# 75%      60.000000              0.000000             3.000000
# max      80.000000              9.000000            11.000000
#
#        Tenure in Months  Avg Monthly Long Distance Charges  \
# count       7043.000000                        7043.000000
# mean          32.386767                          25.446612
# std           24.542061                          13.495466
# min            1.000000                           1.010000
# 25%            9.000000                          14.455000
# ...

# %%
plt.figure(figsize=(15,20))
for i,column in enumerate(num1):
    plt.subplot(6,2,i+1)
    plt.title(column)
    plt.hist(df[column],bins=40)
plt.show()

# %%
for i in num1:
    p1=np.percentile(df[i],25)
    p2=np.percentile(df[i],50)
    p3=np.percentile(df[i],75)
    print(i,'p1:',p1)
    print(i,'p2:',p2)
    print(i,'p3:',p3)
    print('---------------')
# Out:
# Age p1: 32.0
# Age p2: 46.0
# Age p3: 60.0
# ---------------
# Number of Dependents p1: 0.0
# Number of Dependents p2: 0.0
# Number of Dependents p3: 0.0
# ---------------
# Number of Referrals p1: 0.0
# Number of Referrals p2: 0.0
# Number of Referrals p3: 3.0
# ---------------
# Tenure in Months p1: 9.0
# Tenure in Months p2: 29.0
# Tenure in Months p3: 55.0
# ---------------
# Avg Monthly Long Distance Charges p1: 14.455
# Avg Monthly Long Distance Charges p2: 25.69
# Avg Monthly Long Distance Charges p3: 36.394999999999996
# ---------------
# Avg Monthly GB Download p1: 15.0
# Avg Monthly GB Download p2: 21.0
# Avg Monthly GB Download p3: 27.0
# ---------------
# Monthly Charge p1: 30.4
# Monthly Charge p2: 70.05
# Monthly Charge p3: 89.75
# ---------------
# Total Refunds p1: 0.0
# Total Refunds p2: 0.0
# Total Refunds p3: 0.0
# ---------------
# Total Extra Data Charges p1: 0.0
# Total Extra Data Charges p2: 0.0
# Total Extra Data Charges p3: 0.0
# ---------------
# ...

# %%
for i in num1:
    q1=np.quantile(df[i],.25)
    q2=np.quantile(df[i],.50)
    q3=np.quantile(df[i],.75)
    print(i,'q1:',q1)
    print(i,'q2:',q2)
    print(i,'q3:',q3)
    print('---------------')
# Out:
# Age q1: 32.0
# Age q2: 46.0
# Age q3: 60.0
# ---------------
# Number of Dependents q1: 0.0
# Number of Dependents q2: 0.0
# Number of Dependents q3: 0.0
# ---------------
# Number of Referrals q1: 0.0
# Number of Referrals q2: 0.0
# Number of Referrals q3: 3.0
# ---------------
# Tenure in Months q1: 9.0
# Tenure in Months q2: 29.0
# Tenure in Months q3: 55.0
# ---------------
# Avg Monthly Long Distance Charges q1: 14.455
# Avg Monthly Long Distance Charges q2: 25.69
# Avg Monthly Long Distance Charges q3: 36.394999999999996
# ---------------
# Avg Monthly GB Download q1: 15.0
# Avg Monthly GB Download q2: 21.0
# Avg Monthly GB Download q3: 27.0
# ---------------
# Monthly Charge q1: 30.4
# Monthly Charge q2: 70.05
# Monthly Charge q3: 89.75
# ---------------
# Total Refunds q1: 0.0
# Total Refunds q2: 0.0
# Total Refunds q3: 0.0
# ---------------
# Total Extra Data Charges q1: 0.0
# Total Extra Data Charges q2: 0.0
# Total Extra Data Charges q3: 0.0
# ---------------
# ...

# %%
plt.figure(figsize=(15,20))
for i,column in enumerate(num1):
    plt.subplot(6,2,i+1)
    plt.title(column)
    plt.boxplot(df[column])
plt.show()

# %%
q1=np.quantile(df['Avg Monthly GB Download'],0.25)
q2=np.quantile(df['Avg Monthly GB Download'],0.50)
q3=np.quantile(df['Avg Monthly GB Download'],0.75)

Iqr=q3-q1
ub=q3+(1.5*Iqr)
lb=q1-(1.5*Iqr)
con1=df['Avg Monthly GB Download']>ub
con2=df['Avg Monthly GB Download']<lb
outliers_df=df[con1|con2]

# %%
len(outliers_df)
# Out:
# 1089

# %%
v=(len(outliers_df)/len(df))*100
v
# Out:
# 15.46216101093284

# %%
q1=np.quantile(df['Total Revenue'],0.25)
q2=np.quantile(df['Total Revenue'],0.50)
q3=np.quantile(df['Total Revenue'],0.75)

Iqr=q3-q1
ub=q3+(1.5*Iqr)
lb=q1-(1.5*Iqr)
con1=df['Total Revenue']>ub
con2=df['Total Revenue']<lb
outliers_df1=df[con1|con2]

# %%
len(outliers_df1)
# Out:
# 21

# %%
v2=(len(outliers_df1)/len(df))*100

# %%
v2
# Out:
# 0.29816839415022006

# %%
q1=np.quantile(df['Avg Monthly GB Download'],0.25)
q2=np.quantile(df['Avg Monthly GB Download'],0.50)
q3=np.quantile(df['Avg Monthly GB Download'],0.75)

Iqr=q3-q1
ub=q3+(1.5*Iqr)
lb=q1-(1.5*Iqr)
con1=df['Avg Monthly GB Download']<ub
con2=df['Avg Monthly GB Download']>lb
non_outliers_df=df[con1&con2]

# %%
q1=np.quantile(df['Total Revenue'],0.25)
q2=np.quantile(df['Total Revenue'],0.50)
q3=np.quantile(df['Total Revenue'],0.75)

Iqr=q3-q1
ub=q3+(1.5*Iqr)
lb=q1-(1.5*Iqr)
con1=df['Total Revenue']<ub
con2=df['Total Revenue']>lb
non_outliers_df1=df[con1&con2]

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.title('non_outliers data')
plt.hist(non_outliers_df1['Total Revenue'])

plt.subplot(2,2,2)
plt.title('original data')
plt.hist(df['Total Revenue'])

plt.subplot(2,2,3)
plt.title('non_outliers data')
plt.boxplot(non_outliers_df1['Total Revenue'])

plt.subplot(2,2,4)
plt.title('original data')
plt.boxplot(df['Total Revenue'])
plt.show()

# %%
num1
# Out:
# Index(['Age', 'Number of Dependents', 'Number of Referrals',
#        'Tenure in Months', 'Avg Monthly Long Distance Charges',
#        'Avg Monthly GB Download', 'Monthly Charge', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Revenue'],
#       dtype='object')

# %%
q1=np.quantile(df['Avg Monthly GB Download'],0.25)
q2=np.quantile(df['Avg Monthly GB Download'],0.50)
q3=np.quantile(df['Avg Monthly GB Download'],0.75)

Iqr=q3-q1
ub=q3+(1.5*Iqr)
lb=q1-(1.5*Iqr)
con1=df['Avg Monthly GB Download']>ub
con2=df['Avg Monthly GB Download']<lb
outliers_df=df[con1|con2]

# %%
df['Avg Monthly GB Download']=np.clip(df['Avg Monthly GB Download'],lb,ub)

# %%
plt.boxplot(df['Avg Monthly GB Download'])
plt.show()

# %%
q1=np.quantile(df['Total Revenue'],0.25)
q2=np.quantile(df['Total Revenue'],0.50)
q3=np.quantile(df['Total Revenue'],0.75)

Iqr=q3-q1
ub1=q3+(1.5*Iqr)
lb1=q1-(1.5*Iqr)
con1=df['Total Revenue']>ub1
con2=df['Total Revenue']<lb1
outliers_df1=df[con1|con2]

# %%
df['Total Revenue']=np.clip(df['Total Revenue'],lb1,ub1)

# %%
plt.boxplot(df['Total Revenue'])
plt.show()

# %% [markdown]
# **Transformation**

# %%
plt.figure(figsize=(15,20))
for i,column in enumerate(num1):
    plt.subplot(6,2,i+1)
    plt.title(column)
    plt.hist(df[column],bins=40)
plt.show()

# %% [markdown]
# **Skewness check**

# %%
for i in (num1):
    print(i,df[i].skew())
# Out:
# Age 0.1621864486741778
# Number of Dependents 2.1099319807722305
# Number of Referrals 1.4460596247412694
# Tenure in Months 0.24054261407486305
# Avg Monthly Long Distance Charges -0.007875507943378508
# Avg Monthly GB Download 0.5741623893008019
# Monthly Charge -0.27539383432523457
# Total Refunds 4.328516700962804
# Total Extra Data Charges 4.091209238564625
# Total Revenue 0.9138573547250024

# %%
list1=['Avg Monthly GB Download','Monthly Charge',"Total Revenue"]

# %%
df['Total Revenue'] = df['Total Revenue']**(1/3)

# %%
df['Total Revenue'].skew()
# Out:
# -0.07353422213636206

# %%
plt.hist(df['Total Revenue'],bins = 40)
plt.show()

# %%
df['Avg Monthly GB Download']= df['Avg Monthly GB Download']**1

# %%
df['Avg Monthly GB Download'].skew()
# Out:
# 0.5741623893008019

# %%
plt.hist(df['Avg Monthly GB Download'],bins=40)
plt.show()

# %%
df['Monthly Charge'] = df['Monthly Charge']**1

# %%
plt.hist(df['Monthly Charge'],bins=40)
plt.show()

# %%
sns.distplot(df['Total Revenue'])
plt.show()

# %% [markdown]
# **Bivariate and Multivariate**

# %%
# for i in cat1[1:]:
 #   for j in cat1[2:]:
  #      if i!=j:
   #         df[[i,j]].value_counts().plot(kind='bar')
          
            
#             plt.subplot(12,3,l+1)
    #    plt.figure(figsize=(2,2))
     #   plt.show()

# %%
cat1
# Out:
# Index(['Gender', 'Married', 'City', 'Phone Service', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Online Security', 'Online Backup',
#        'Device Protection Plan', 'Premium Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract',
#        'Paperless Billing', 'Payment Method', 'Customer Status'],
#       dtype='object')

# %%
col1=df['Gender']
col2=df['Multiple Lines']
res=pd.crosstab(col1,col2)
res
# Out:
# Multiple Lines    No   Yes
# Gender
# Female          2002  1486
# Male            2070  1485

# %%
plt.figure(figsize=(2,2))
res.plot(kind='bar')
plt.show()

# %%
col1=df['Gender']
col2=df['Streaming TV']
res1=pd.crosstab(col1,col2)
res1
# Out:
# Streaming TV    No   Yes
# Gender
# Female        2133  1355
# Male          2203  1352

# %%
res1.plot(kind='bar')
plt.show()

# %%
col1=df['Online Security']
col2=df['Streaming TV']
res2=pd.crosstab(col1,col2)
res2
# Out:
# Streaming TV       No   Yes
# Online Security
# No               3366  1658
# Yes               970  1049

# %%
res2.plot(kind='bar')
plt.show()

# %% [markdown]
# **Multivariate**

# %%
col1=df['Gender']
col2=df['Internet Type']
col3=df['Phone Service']
col=[col2,col3]
dee=pd.crosstab(col1,col)

# %%
dee.plot(kind='bar')
plt.show()

# %% [markdown]
# **NUm Vs Num**

# %%
num1
# Out:
# Index(['Age', 'Number of Dependents', 'Number of Referrals',
#        'Tenure in Months', 'Avg Monthly Long Distance Charges',
#        'Avg Monthly GB Download', 'Monthly Charge', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Revenue'],
#       dtype='object')

# %%
plt.scatter(df['Tenure in Months'],df['Monthly Charge'])

# %%
plt.scatter(df['Age'],df['Monthly Charge'])

# %%
plt.scatter(df['Age'],df['Total Refunds'])

# %%
cat1
# Out:
# Index(['Gender', 'Married', 'City', 'Phone Service', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Online Security', 'Online Backup',
#        'Device Protection Plan', 'Premium Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Contract',
#        'Paperless Billing', 'Payment Method', 'Customer Status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for i in cat1:
    df[i]=LE.fit_transform(df[i])

# %%
df
# Out:
#       Gender  Age  Married  Number of Dependents  City  Number of Referrals  \
# 0          0   37        1                     0   346                    2
# 1          1   46        0                     0   368                    0
# 2          1   50        0                     0   222                    0
# 3          1   78        1                     0   587                    1
# 4          0   75        1                     0   139                    3
# ...      ...  ...      ...                   ...   ...                  ...
# 7038       0   20        0                     0   490                    0
# 7039       1   40        1                     0   827                    1
# 7040       1   22        0                     0   296                    0
# 7041       1   21        1                     0   930                    5
# 7042       1   36        1                     0   920                    1
#
# ...

# %% [markdown]
# **Correlation**

# %%
corr=df[num1].corr()

# %%
corr
# Out:
#                                         Age  Number of Dependents  \
# Age                                1.000000             -0.119000
# Number of Dependents              -0.119000              1.000000
# Number of Referrals               -0.025141              0.278003
# Tenure in Months                   0.009927              0.108237
# Avg Monthly Long Distance Charges -0.019059             -0.002670
# Avg Monthly GB Download           -0.495797              0.241854
# Monthly Charge                     0.134511             -0.125649
# Total Refunds                      0.024168              0.014023
# Total Extra Data Charges           0.025036             -0.014436
# Total Revenue                      0.054928              0.055920
#
#                                    Number of Referrals  Tenure in Months  \
# Age                                          -0.025141          0.009927
# Number of Dependents                          0.278003          0.108237
# ...

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
X=df.drop('Customer Status',axis=1)

y=df['Customer Status']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1234)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()
